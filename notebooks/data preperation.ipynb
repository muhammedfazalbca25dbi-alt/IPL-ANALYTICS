# %%
import sqlite3
import pandas as pd
con=sqlite3.connect(r'C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\data\raw\ipl.db')


def q(sql):
     return pd.read_sql(sql, con)

# %%
q("""select * from matches;""")
# Out:
#       match_id  season_id  balls_per_over            city  match_date  \
# 0       335982       2008               6       Bangalore  2008-04-18
# 1      1082591       2017               6       Hyderabad  2017-04-05
# 2      1082592       2017               6            Pune  2017-04-06
# 3      1082593       2017               6          Rajkot  2017-04-07
# 4      1082594       2017               6          Indore  2017-04-08
# ...        ...        ...             ...             ...         ...
# 1207   1529282       2026               6           Delhi  2026-04-27
# 1208   1529283       2026               6  New Chandigarh  2026-04-28
# 1209   1529284       2026               6          Mumbai  2026-04-29
# 1210   1529285       2026               6       Ahmedabad  2026-04-30
# 1211   1529286       2026               6          Jaipur  2026-05-01
#
#                  event_name  match_number gender match_type format  ...  \
# ...

# %%
def run_sql_file(path):
    with open(path,'r') as f:
        script=f.read()
    con.executescript(script)
    con.commit()
    print('ran',path)

# %%
run_sql_file(r"C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\01_nulls_and_blanks.sql")
# Out:
# ran C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\01_nulls_and_blanks.sql

# %%
run_sql_file(r"C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\02_merge_categories.sql")
# Out:
# ran C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\02_merge_categories.sql

# %%
q("""select count (*) as blank_before
from players
where trim(field_pos)='';""")
# Out:
#    blank_before
# 0           612

# %%
q("""select count(*) as  null_after
from v_players_clean
where field_pos_clean is null;""")
# Out:
#    null_after
# 0         700

# %%
q("""select distinct team_name
from teams
order by team_name;""")
# Out:
#                       team_name
# 0           Chennai Super Kings
# 1               Deccan Chargers
# 2                Delhi Capitals
# 3                 Gujarat Lions
# 4                Gujarat Titans
# 5          Kochi Tuskers Kerala
# 6         Kolkata Knight Riders
# 7          Lucknow Super Giants
# 8                Mumbai Indians
# 9                 Pune Warriors
# 10                 Punjab Kings
# 11             Rajasthan Royals
# 12       Rising Pune Supergiant
# 13      Rising Pune Supergiants
# 14  Royal Challengers Bangalore
# 15          Sunrisers Hyderabad

# %%
q("""select distinct team_name_clean
from v_teams_clean
order by team_name_clean;""")
# Out:
#                 team_name_clean
# 0           Chennai Super Kings
# 1               Deccan Chargers
# 2                Delhi Capitals
# 3                 Gujarat Lions
# 4                Gujarat Titans
# 5          Kochi Tuskers Kerala
# 6         Kolkata Knight Riders
# 7          Lucknow Super Giants
# 8                Mumbai Indians
# 9                 Pune Warriors
# 10                 Punjab Kings
# 11             Rajasthan Royals
# 12       Rising Pune Supergiant
# 13  Royal Challengers Bangalore
# 14          Sunrisers Hyderabad

# %%
run_sql_file(r"C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\03_venue_names.sql")
# Out:
# ran C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\03_venue_names.sql

# %%
q("""SELECT venue, COUNT(*) AS matches
FROM matches
WHERE venue IN ('Wankhede Stadium', 'Wankhede Stadium, Mumbai')
GROUP BY venue;""")
# Out:
#                       venue  matches
# 0          Wankhede Stadium       73
# 1  Wankhede Stadium, Mumbai       57

# %%
q("""SELECT venue, COUNT(*) AS matcheS
FROM matcheS
GROUP BY venue
ORDER BY matcheS DESC LIMIT 5;""")
# Out:
#                       venue  matcheS
# 0              Eden Gardens       77
# 1          Wankhede Stadium       73
# 2     M Chinnaswamy Stadium       65
# 3          Feroz Shah Kotla       60
# 4  Wankhede Stadium, Mumbai       57

# %%
q("""SELECT venue_clean,COUNT(*) AS matches
FROM v_matches_venue
GROUP BY venue_clean
ORDER BY matches DESC LIMIT 5;""")
# Out:
#                           venue_clean  matches
# 0                    Wankhede Stadium      130
# 1               M Chinnaswamy Stadium      104
# 2                        Eden Gardens      104
# 3              MA Chidambaram Stadium       95
# 4  Rajiv Gandhi International Stadium       87

# %%
run_sql_file(r"C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\04_dedupe_venues.sql")
# Out:
# ran C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\04_dedupe_venues.sql

# %%
q("""SELECT COUNT(*) AS rows, COUNT(DISTINCT venue)AS names 
from venues;
""")
# Out:
#    rows  names
# 0    63     59

# %%
q("""select count(*),venue,city
from venues
group by venue
order by count(*) desc
limit 5;""")
# Out:
#    count(*)                                              venue       city
# 0         2                            Sharjah Cricket Stadium       None
# 1         2  Maharaja Yadavindra Singh International Cricke...     Mohali
# 2         2                Dubai International Cricket Stadium       None
# 3         2                 Dr DY Patil Sports Academy, Mumbai     Mumbai
# 4         1                   Zayed Cricket Stadium, Abu Dhabi  Abu Dhabi

# %%
q("""SELECT COUNT(*) AS rows, COUNT(DISTINCT venue)AS names 
from v_venues_clean;
""")
# Out:
#    rows  names
# 0    59     59

# %%
q("""select count(*),venue,city
from v_venues_clean
group by venue
order by count(*) desc
limit 10;""")
# Out:
#    count(*)                                             venue            city
# 0         1                  Zayed Cricket Stadium, Abu Dhabi       Abu Dhabi
# 1         1                          Wankhede Stadium, Mumbai          Mumbai
# 2         1                                  Wankhede Stadium          Mumbai
# 3         1      Vidarbha Cricket Association Stadium, Jamtha          Nagpur
# 4         1                                   SuperSport Park       Centurion
# 5         1                        Subrata Roy Sahara Stadium            Pune
# 6         1                                  St George's Park  Port Elizabeth
# 7         1                              Sheikh Zayed Stadium       Abu Dhabi
# 8         1                           Sharjah Cricket Stadium         Sharjah
# 9         1  Shaheed Veer Narayan Singh International Stadium          Raipur

# %%
run_sql_file(r"C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\05_city_fallback.sql ")
# Out:
# ran C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\05_city_fallback.sql

# %%
q("""select venue,count(*) as no_city
from matches
where city is null
group by venue;""")
# Out:
#                                  venue  no_city
# 0  Dubai International Cricket Stadium       33
# 1              Sharjah Cricket Stadium       18

# %%
q("""select city_clean from v_city_clean
where city_clean is null;
""")
# Out:
# Empty DataFrame
# Columns: [city_clean]
# Index: []

# %%
q("""select city_clean
from v_city_clean;""")
# Out:
#           city_clean
# 0          Bangalore
# 1          Hyderabad
# 2               Pune
# 3             Rajkot
# 4             Indore
# ...              ...
# 1207           Delhi
# 1208  New Chandigarh
# 1209          Mumbai
# 1210       Ahmedabad
# 1211          Jaipur
#
# [1212 rows x 1 columns]

# %%
run_sql_file(r"C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\06_season_year.sql")
# Out:
# ran C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\06_season_year.sql

# %%
q("""select season,
count(*) as matches
from matches
where season = '2021/21'
group by season;
""")
# Out:
# Empty DataFrame
# Columns: [season, matches]
# Index: []

# %%
q("""SELECT season, 
COUNT(*) AS matches
FROM matches
WHERE season ='2020/21' 
GROUP BY season;
""")
# Out:
#     season  matches
# 0  2020/21       60

# %%
q("""SELECT DISTINCT season, season_year
FROM v_season WHERE season = '2020/21';""")
# Out:
#     season  season_year
# 0  2020/21         2020

# %%
run_sql_file(r"C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\07_win_definition.sql")
# Out:
# ran C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\07_win_definition.sql

# %%
run_sql_file(r"C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\08_matches_clean.sql")
# Out:
# ran C:\Users\muham\OneDrive\Desktop\SEMSTER 3\project 3.1_sem 3\sql\08_matches_clean.sql

# %%
q("""SELECT * from matches_clean;""")
# Out:
#       match_id                                        venue_clean  \
# 0       335982                              M Chinnaswamy Stadium
# 1      1082591                 Rajiv Gandhi International Stadium
# 2      1082592            Maharashtra Cricket Association Stadium
# 3      1082593             Saurashtra Cricket Association Stadium
# 4      1082594                             Holkar Cricket Stadium
# ...        ...                                                ...
# 1207   1529282                               Arun Jaitley Stadium
# 1208   1529283  Maharaja Yadavindra Singh International Cricke...
# 1209   1529284                                   Wankhede Stadium
# 1210   1529285                              Narendra Modi Stadium
# 1211   1529286                             Sawai Mansingh Stadium
#
#           city_clean  season_year result                 match_winner  \
# 0          Bangalore         2008    win        Kolkata Knight Riders
# ...

# %%
import ast 
import pandas as pd
d=pd.read_sql('select*from deliveries where fielders_involved is not null',con)
d['fielders']=d['fielders_involved'].apply(ast.literal_eval)
d=d.explode('fielders')
d['fielders'].value_counts().head(10)
# Out:
# fielders
# MS Dhoni          258
# KD Karthik        228
# RV Uthappa        169
# AB de Villiers    148
# V Kohli           142
# WP Saha           139
# SV Samson         134
# RA Jadeja         129
# SK Raina          119
# RR Pant           119
# Name: count, dtype: int64
